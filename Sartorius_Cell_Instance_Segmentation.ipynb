# %% [markdown]
# <a href="https://colab.research.google.com/github/amitf1/Birds_Classifier/blob/master/Sartorius_Cell_Instance_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import glob
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
DOWNLOAD_KAGGLE_DATA = False

# %% [markdown]
# ### Colab Drive & Kaggle Setup

# %%
if 'google.colab' in str(get_ipython()):
  from google.colab import drive
  drive.mount('/content/drive')
  # %cd /content/drive/MyDrive/Kaggle/Sartorius - Cell Instance Segmentation
  data_path = r"/content/drive/MyDrive/Kaggle/Sartorius - Cell Instance Segmentation"
# Out:
# Mounted at /content/drive

# %%
if DOWNLOAD_KAGGLE_DATA:
  os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/Kaggle"
  # !kaggle competitions download -c sartorius-cell-instance-segmentation

# %%
# !ls

# %% [markdown]
# ### Data Visualization and EDA

# %%
data = glob.glob(os.path.join(data_path, '*.png'))

# %%
def show_rand_n_images(data, n, rows, cols):
  rand_images = np.random.choice(data, n)
  fig, ax = plt.subplots(rows,cols, figsize=(20,15))
  ax = ax.ravel()
  for i, image_path in enumerate(rand_images):
    img = cv2.imread(image_path)
    ax[i].set_title(os.path.basename(image_path))
    ax[i].axis("off")
    ax[i].imshow(img);

# %%
show_rand_n_images(data, 4, 2, 2)
